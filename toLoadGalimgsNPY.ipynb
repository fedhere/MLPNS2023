# %% [markdown]
# <a href="https://colab.research.google.com/github/fedhere/MLPNS2021/blob/main/toLoadGalimgsNPY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My\ Drive/MLPNS2021
# Out:
# /content/drive/My Drive/MLPNS2021

# %%
import numpy as np
gals_ = np.load("galimgs.npy")
# Out:
# array([[[[  1,   3,   3],
#          [  1,   3,   3],
#          [  1,   3,   3],
#          ...,
#          [  0,   0,   0],
#          [  0,   2,   2],
#          [  3,   5,   5]],
#
#         [[  1,   3,   3],
#          [  1,   3,   3],
#          [  1,   3,   3],
#          ...,
#          [  0,   2,   2],
#          [  1,   3,   3],
#          [  2,   4,   4]],
#
#         [[  0,   2,   2],
#          [  0,   2,   2],
#          [  0,   2,   2],
#          ...,
#          [  4,   6,   6],
#          [  3,   5,   5],
#          [  0,   2,   2]],
#
#         ...,
#
#         [[  3,   5,   5],
#          [  0,   0,   0],
#          [  0,   0,   0],
#          ...,
#          [ 23,  19,  18],
#          [ 20,  18,  17],
#          [ 16,  19,  17]],
#
#         [[  1,   3,   3],
#          [  0,   0,   0],
#          [  2,   4,   4],
#          ...,
#          [ 29,  25,  24],
#          [ 24,  22,  21],
#          [ 19,  22,  20]],
#
#         [[  0,   2,   2],
# ...

# %%
gals_.shape
