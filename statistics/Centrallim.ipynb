# %% [markdown]
# <a href="https://colab.research.google.com/github/fedhere/MLPNS_FBianco/blob/main/statistics/Centrallim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pylab as pl
import numpy as np
import scipy as sp
from scipy import stats
import seaborn
seaborn.set_style("darkgrid")

# %%
np.random.seed(456)
mymean = 100

# %%
df = mymean #chi2
p = 0.5 #binomial
n = mymean / p# mean = n*p #binomial

mydist = {}

pl.hist(np.random.chisquare(mymean, size=500));
pl.ylabel('N')
pl.xlabel('x');

# %%
mysize = (np.random.rand(100) * 2000).astype(int)

mysize[mysize < 10] = 10 # make sure all are > 10
pl.plot(mysize, '.');

# %%
for s in mysize:
  mydist[s] = np.random.chisquare(mymean, size=s)

ax = pl.figure().add_subplot(111)

for d in mydist.keys():
  ax.plot(d, mydist[d].mean(), '.')
ax.plot(pl.xlim(), [100, 100], 'k', alpha=0.5)
ax.set_xlabel("sample size")
ax.set_xlabel("sample mean");
